# %%
#importing packages 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.set(color_codes = True)

# %% [markdown]
# ## Creating Histogram for One Subject's Fixation Distribution

# %%
#reading in cleaned dataset for Aesthetic Task
aes_df = pd.read_csv("SM01_Retest_Aesthetic_Task.csv", index_col = 0)
aes_df
# Out:
#         subj                    image       task  fixN  locs_1  locs_2  durs  \
# 2599       1            target_closet  aesthetic    13   387.0   113.0   175
# 2646       1        target_coffeeshop  aesthetic    18   381.0   647.0   291
# 2540       1          target_cemetery  aesthetic    31   304.0   462.0   165
# 2489       1           target_busstop  aesthetic    19   146.0   312.0   122
# 2853       1           target_desktop  aesthetic    31   415.0   839.0   464
# ...      ...                      ...        ...   ...     ...     ...   ...
# 340082   100             target_train  aesthetic    34   439.0   868.0   333
# 340081   100             target_train  aesthetic    33   509.0   822.0   292
# 340080   100             target_train  aesthetic    32   453.0   855.0   305
# 340090   100            target_tunnel  aesthetic     6   232.0   807.0   218
# 338421   100  target_livingroom_IDS01  aesthetic    13   360.0   575.0   227
#
#         SCamp
# 2599     2.17
# 2646     1.39
# 2540     6.58
# 2489     9.07
# 2853     2.80
# ...       ...
# 340082   1.10
# 340081   2.07
# 340080   1.61
# 340090   5.07
# 338421   5.03
#
# [156096 rows x 8 columns]

# %%
aes_sub = aes_df.durs.loc[aes_df["subj"] == 1]
aes_sub
# Out:
# 2599    175
# 2646    291
# 2540    165
# 2489    122
# 2853    464
#        ...
# 3358    220
# 3359    567
# 3360    139
# 3187    170
# 3216    193
# Name: durs, Length: 414, dtype: int64

# %%
# raw and fitted, smaller bin size
aes_plot = sns.distplot(aes_sub)
plt.axvline(aes_sub.mean(), color = "red", label = "mean")
plt.text(x = aes_sub.mean() + 3, y = max([h.get_height() for h in aes_plot.patches]), s = "mean", color = "red")
plt.axvline(152, color = "purple", label = "mu")
plt.text(x = 152 + 3, y = max([h.get_height() for h in aes_plot.patches]), s = "mu", color = "purple")
# Out:
# Text(155, 0.005168249208728968, 'mu')

# %%
# put lines for raw mean, Mu, Tau

# %% [markdown]
# ## Creating Histogram for Ex-Gauss Values Across Participants

# %% [markdown]
# ### Aesthetic Task

# %%
#reading in qmpe values for aesthetic 
aes_qmpe_df = pd.read_csv("Aes_Zscore_Final.csv", index_col =0)
aes_qmpe_df
# Out:
#     subject  Mem_Update     OSPAN      RAPM         Tau          Mu  \
# 0         1   -0.081524 -0.322953  1.342009  106.724458  152.070800
# 1         2    0.955907  0.918399 -0.620930  120.855988  154.362654
# 2         3    1.130691  0.363323  0.949421  111.727054  150.132526
# 3         4    0.465382  1.120244 -0.228342  172.398595  213.271239
# 4         5    0.899524  1.009229  1.734597  123.166384  153.375971
# 5         6    0.420277  1.009229 -1.406105   99.036833  142.774136
# 6         7   -1.372674  1.009229 -1.013517  175.320817  150.662466
# 7         8   -0.763747  0.867937  0.949421   92.242802  192.837692
# 8         9    2.117378  1.291813  0.949421  103.864945  190.251821
# 9        10    0.048155 -1.049598  0.556834  118.786518  139.051999
# 10       11    1.198350 -1.402829 -1.406105  163.625627  182.220748
# 11       12    0.696549  0.242215  0.556834   45.717286  191.254040
# 12       13   -1.242995  0.040369  0.949421  100.860968  160.015389
# 3   78.252791  4.622512
# 4   57.314410  5.075996
# 5   34.428104  4.744921
# 6   37.365567  3.687005
# 7   57.111976  4.215256
# 8   55.178194  5.270961
# 9   25.429333  2.570770
# 10  55.421416  5.148260
# 11  54.123500  5.180262
# 12  54.050552  4.992324
# 13  65.520416  5.029228
# 14  50.212824  4.627703
# 15  45.642607  5.114119
# 16  38.690303  4.835474
# 17  56.227008  4.383763
# 18  57.038605  5.086204
# 19  48.286386  5.446835
# 20  35.550119  4.903516
# 21  39.625252  4.186256
# 22  46.158589  4.681488
# 23  75.915699  5.830144
# 24  34.388258  3.871142
# 25  55.575422  3.462777
# 26  52.531402  4.385365
# 27  41.262472  4.817029
# 28  37.726481  5.164463
# 29  51.169560  4.799866
# ..        ...       ...
# 68  70.803872  3.728668
# 69  63.271945  4.442510
# 70  58.647918  5.290012
# 71  46.886501  4.739487
# 72  64.958967  5.961137
# 73  62.795961  4.600399
# 74  60.164546  6.103934
# 75  20.613397  4.470197
# 76  21.674001  4.292460
# 77  52.728523  5.366982
# 78  44.810207  4.333367
# 79  73.160200  4.017699
# 80  39.322533  3.102672
# 81  53.669163  4.225900
# 82  50.507335  4.412038
# 83  32.860987  3.846148
# 84  45.676336  4.184039
# 85  45.862791  3.738537
# 86  25.046657  3.766705
# 87  44.653446  5.248224
# 88  33.757780  2.944082
# 89  55.996694  5.015586
# 90  34.180375  3.126342
# 91  43.706243  4.859743
# 92  51.160076  5.746412
# 93  43.798247  5.177854
# 94  40.267784  5.360244
# 95  52.259217  6.095942
# 96  48.068816  4.655413
# 97  57.247680  4.608360
#
# [98 rows x 8 columns]

# %%
#variability in the mu parameter for aesthetic task
aes_mu = aes_qmpe_df.Mu
sns.distplot(aes_mu)

# %%
#variability in the sigma parameter for aesthetic task
aes_sig = aes_qmpe_df.Sigma
sns.distplot(aes_sig)

# %%
#variability in the tau parameter for aesthetic task
aes_tau = aes_qmpe_df.Tau
sns.distplot(aes_tau)

# %% [markdown]
# ### Memorize Task

# %%
#reading in qmpe values for memorize
mem_qmpe_df = pd.read_csv("Mem_Zscore_Final.csv", index_col = 0)
mem_qmpe_df
# Out:
#     subject  Mem_Update     OSPAN      RAPM         Tau          Mu  \
# 0         1   -0.081524 -0.322953  1.342009  102.721089  139.883892
# 1         2    0.955907  0.918399 -0.620930   97.656617  163.986945
# 2         3    1.130691  0.363323  0.949421  102.457896  124.041671
# 3         4    0.465382  1.120244 -0.228342  150.668076  208.590699
# 4         5    0.899524  1.009229  1.734597  112.829027  149.215281
# 5         6    0.420277  1.009229 -1.406105  111.234232  138.600175
# 6         7   -1.372674  1.009229 -1.013517  165.884528  132.957235
# 7         8   -0.763747  0.867937  0.949421   96.223102  183.588432
# 8         9    2.117378  1.291813  0.949421  115.347758  188.511885
# 9        10    0.048155 -1.049598  0.556834  119.374268  129.667358
# 10       11    1.198350 -1.402829 -1.406105  142.146801  160.083175
# 11       12    0.696549  0.242215  0.556834   57.274642  180.775421
# 12       13   -1.242995  0.040369  0.949421  108.383219  153.967089
# 13       14   -1.180975 -0.222030 -1.798693  144.647529  152.891955
# 14       15   -0.910341  1.009229 -1.013517   68.695250  162.963455
# 8   59.701668  4.789211
# 9   26.885107  2.826130
# 10  68.386994  4.768942
# 11  53.445753  5.524530
# 12  53.869475  5.128836
# 13  52.356170  5.330290
# 14  44.703598  4.208144
# 15  53.455232  4.912685
# 16  36.391668  4.905056
# 17  40.567095  4.384934
# 18  59.830570  3.880150
# 19  41.451403  4.762500
# 20  46.458497  4.873774
# 21  34.717321  4.002926
# 22  47.066357  4.301314
# 23  94.232538  6.075220
# 24  23.287588  3.701906
# 25  76.222014  3.382385
# 26  50.042046  4.615186
# 27  37.915640  5.129819
# 28  61.140314  5.124860
# 29  51.573548  4.562111
# ..        ...       ...
# 68  50.594872  3.349606
# 69  56.687584  4.184752
# 70  57.805188  4.781406
# 71  30.478276  3.832120
# 72  56.470164  6.327185
# 73  54.973905  5.321927
# 74  57.923565  6.731765
# 75  10.586418  3.471688
# 76  40.965538  4.387146
# 77  53.207124  5.582325
# 78  30.675975  4.165317
# 79  60.427431  3.617158
# 80  38.666614  3.664872
# 81  11.486804  3.105898
# 82  52.583869  4.268486
# 83  30.477447  4.465594
# 84  27.014066  3.888583
# 85  55.343539  3.673604
# 86  25.154025  4.522734
# 87  45.357029  4.720042
# 88  39.414235  2.846491
# 89  48.771753  4.504958
# 90  25.642590  2.861006
# 91  34.474132  4.799093
# 92  49.918119  4.762193
# 93  46.483953  5.315152
# 94  48.134280  5.367663
# 95  50.052154  5.470351
# 96  58.116578  4.214751
# 97  56.750258  4.140688
#
# [98 rows x 8 columns]

# %%
#variability in the mu parameter for memorize task
mem_mu = mem_qmpe_df.Mu
sns.distplot(mem_mu)

# %%
#variability in the sigma parameter for memorize task
mem_sig = mem_qmpe_df.Sigma
sns.distplot(mem_sig)

# %%
#variability in the tau parameter for memorize task
mem_tau = mem_qmpe_df.Tau
sns.distplot(mem_tau)

# %% [markdown]
# ## Scatterplots

# %% [markdown]
# ### Aesthetic Task

# %%
aes_long_df = pd.read_csv("Aes_Long_Final.csv", index_col = 0)
aes_long_df.head()
# Out:
#    subject        Test     Score          Mu      Sigma         Tau     SCamp
# 0        1  Mem_Update -0.081524  152.070800  45.234478  106.724458  4.607705
# 1        2  Mem_Update  0.955907  154.362654  42.322657  120.855988  4.350217
# 2        3  Mem_Update  1.130691  150.132526  40.677544  111.727054  4.196172
# 3        4  Mem_Update  0.465382  213.271239  78.252791  172.398595  4.622512
# 4        5  Mem_Update  0.899524  153.375971  57.314410  123.166384  5.075996

# %%
sns.lmplot(x="Mu", y="Score", hue="Test", data= aes_long_df)

# %%
sns.set_style("white")
sns.set_style("ticks")

# %%
aes_mu = sns.lmplot(x="Score", y="Mu", hue="Test", data= aes_long_df)
sns.despine()
aes_mu = aes_mu.fig
aes_mu.savefig("Aes_Mu_Scatterplot_HD.png", dpi = 300)

# %%
sns.lmplot(x="Sigma", y="Score", hue="Test", data= aes_long_df)

# %%
aes_sig = sns.lmplot(x="Score", y="Sigma", hue="Test", data= aes_long_df)
aes_sig.set(ylim = (0, 100))
sns.despine()
aes_sig = aes_sig.fig
aes_sig.savefig("Aes_Sigma_Scatterplot_HD.png", dpi =300)

# %%
sns.lmplot(x="Tau", y="Score", hue="Test", data= aes_long_df)

# %%
aes_tau = sns.lmplot(x="Score", y="Tau", hue="Test", data= aes_long_df)
sns.despine()
aes_tau = aes_tau.fig
aes_tau.savefig("Aes_Tau_Scatterplot_HD.png", dpi = 300)

# %%
sns.lmplot(x="SCamp", y="Score", hue="Test", data= aes_long_df)

# %%
aes_scamp = sns.lmplot(x="Score", y="SCamp", hue="Test", data= aes_long_df)
aes_scamp.set(ylim = (2, 7))
sns.despine()
aes_scamp = aes_scamp.fig
aes_scamp.savefig("Aes_SCamp_Scatterplot_HD.png", dpi = 300)

# %% [markdown]
# ### Memorize Task

# %%
mem_long_df = pd.read_csv("Mem_Long_Final.csv", index_col = 0)
mem_long_df.head()
# Out:
#    subject        Test     Score          Mu      Sigma         Tau     SCamp
# 0        1  Mem_Update -0.081524  139.883892  37.807063  102.721089  4.679519
# 1        2  Mem_Update  0.955907  163.986945  57.422247   97.656617  4.817836
# 2        3  Mem_Update  1.130691  124.041671  41.459446  102.457896  3.981049
# 3        4  Mem_Update  0.465382  208.590699  98.266527  150.668076  4.165634
# 4        5  Mem_Update  0.899524  149.215281  64.349666  112.829027  4.686260

# %%
sns.lmplot(x="Mu", y="Score", hue="Test", data= mem_long_df)

# %%
mem_mu = sns.lmplot(x="Score", y="Mu", hue="Test", data= mem_long_df)
sns.despine()
mem_mu = mem_mu.fig
mem_mu.savefig("Mem_Mu_Scatterplot_HD.png", dpi = 300)

# %%
sns.lmplot(x="Sigma", y="Score", hue="Test", data= mem_long_df)

# %%
mem_sig = sns.lmplot(x="Score", y="Sigma", hue="Test", data= mem_long_df)
sns.despine()
mem_sig = mem_sig.fig
mem_sig.savefig("Mem_Sigma_Scatterplot_HD.png", dpi = 300)

# %%
sns.lmplot(x="Tau", y="Score", hue="Test", data= mem_long_df)

# %%
mem_tau = sns.lmplot(x="Score", y="Tau", hue="Test", data= mem_long_df)
sns.despine()
mem_tau = mem_tau.fig
mem_tau.savefig("Mem_Tau_Scatterplot_HD.png", dpi = 300)

# %%
sns.lmplot(x="SCamp", y="Score", hue="Test", data= mem_long_df)

# %%
mem_scamp = sns.lmplot(x="Score", y="SCamp", hue="Test", data= mem_long_df)
mem_scamp.set(ylim = (2, 7))
mem_scamp = mem_scamp.fig
mem_scamp.savefig("Mem_SCamp_Scatterplot_HD.png", dpi = 300)

# %%
mem_scamp = sns.lmplot(x="Score", y="SCamp", hue="Test", ci = 95, data= mem_long_df)
mem_scamp.set(ylim = (2, 7))
#mem_scamp = mem_scamp.fig
#mem_scamp.savefig("Mem_SCamp_Scatterplot_HD.png", dpi = 300)

# %% [markdown]
# ## Task Boxplots

# %%
both_task_df = pd.read_csv("Task_Zscore_Final.csv", index_col = 0)
both_task_df
# Out:
#      subject  Mem_Update     OSPAN      RAPM         Tau          Mu  \
# 0          1   -0.081524 -0.322953  1.342009  106.724458  152.070800
# 1          2    0.955907  0.918399 -0.620930  120.855988  154.362654
# 2          3    1.130691  0.363323  0.949421  111.727054  150.132526
# 3          4    0.465382  1.120244 -0.228342  172.398595  213.271239
# 4          5    0.899524  1.009229  1.734597  123.166384  153.375971
# ..       ...         ...       ...       ...         ...         ...
# 191       96    0.499212  0.746830  0.556834  117.648505  166.328992
# 192       97    0.341342 -0.181661  0.164246   94.897275  179.387099
# 193       98    1.006650 -0.464245  0.556834  142.656224  130.022492
# 194       99    1.096862 -0.625722  1.734597  134.467817  173.345881
# 195      100   -0.318329 -0.121108 -0.620930  115.391556  190.063484
#
#          Sigma     SCamp       Task
# 0    45.234478  4.607705  Aesthetic
# 1    42.322657  4.350217  Aesthetic
# 2    40.677544  4.196172  Aesthetic
# 3    78.252791  4.622512  Aesthetic
# 4    57.314410  5.075996  Aesthetic
# ..         ...       ...        ...
# 191  46.483953  5.315152   Memorize
# 192  48.134280  5.367663   Memorize
# 193  50.052154  5.470351   Memorize
# 194  58.116578  4.214751   Memorize
# 195  56.750258  4.140688   Memorize
#
# [196 rows x 9 columns]

# %%
#sns.set_style("white")
#sns.set_style("ticks")
mu_box = sns.boxplot( x = "Task", y = "Mu", data = both_task_df)
sns.despine()
mu_box = mu_box.get_figure()
mu_box.savefig("Mu_Boxplot.png", dpi = 300)

# %%
sig_box = sns.boxplot( x = "Task", y = "Sigma", data = both_task_df)
sns.despine()
sig_box = sig_box.get_figure()
sig_box.savefig("Sigma_Boxplot.png", dpi = 300)

# %%
tau_box = sns.boxplot( x = "Task", y = "Tau", data = both_task_df)
sns.despine()
tau_box = tau_box.get_figure()
tau_box.savefig("Tau_Boxplot.png", dpi = 300)

# %%
scamp_box = sns.boxplot( x = "Task", y = "SCamp", data = both_task_df)
sns.despine()
scamp_box = scamp_box.get_figure()
scamp_box.savefig("SCamp_Boxplot.png", dpi = 300)

# %% [markdown]
# ## Flipped Axis Scatterplots

# %%
sns.lmplot(x="Score", y="Tau", hue="Test", data= aes_long_df)

# %% [markdown]
# ## Creating Scatterplots for Working Memory and Ex-Gauss Parameters

# %% [markdown]
# ### Aesthetic Task

# %% [markdown]
# #### OSPAN

# %%
#relationship between OSPAN performance and Mu
sns.jointplot(x="OSPAN", y="Mu", data=aes_qmpe_df, kind = "reg")

# %%
#Relationship between OSPAN performance and Sigma
sns.jointplot(x="OSPAN", y="Sigma", data=aes_qmpe_df, kind = "reg")

# %%
#relationship between OSPAN performance and Tau
sns.jointplot(x="OSPAN", y="Tau", data=aes_qmpe_df, kind = "reg")

# %% [markdown]
# ## Histograms for Raw Partial Scores

# %%
raw_ids = pd.read_csv("ID_Raw_Part.csv", index_col = 0)
raw_ids
# Out:
#     MU_Partial  OSPAN_Partial      RAPM
# 0     0.489216          0.840  0.750000
# 1     0.669608          0.963  0.333333
# 2     0.700000          0.908  0.666667
# 3     0.584314          0.983  0.416667
# 4     0.659804          0.972  0.833333
# ..         ...            ...       ...
# 93    0.590196          0.946  0.583333
# 94    0.562745          0.854  0.500000
# 95    0.678431          0.826  0.583333
# 96    0.694118          0.810  0.833333
# 97    0.448039          0.860  0.333333
#
# [98 rows x 3 columns]

# %%
#histogram of the raw partial memory updating scores
mu_part = raw_ids.MU_Partial
sns.distplot(mu_part)

# %%
#histogram of the raw partial OSPAN scores
ospan_part = raw_ids.OSPAN_Partial
sns.distplot(ospan_part)

# %%
#histogram of the raw partial RAPM scores
rapm_part = raw_ids.RAPM
sns.distplot(rapm_part)

# %%
eye_file = pd.read_csv("SM01_full_table_Order.csv")
eye_file
# Out:
#         subj                    image      task  fixN  locs_1  locs_2  durs  \
# 0          1  target_diningroom_IDS01  memorize     1     NaN     NaN   543
# 1          1  target_diningroom_IDS01  memorize     2   384.0   677.0   336
# 2          1  target_diningroom_IDS01  memorize     3   482.0   784.0   298
# 3          1  target_diningroom_IDS01  memorize     4   526.0   613.0   215
# 4          1  target_diningroom_IDS01  memorize     5   330.0   534.0   236
# 5          1  target_diningroom_IDS01  memorize     6   321.0   508.0   321
# 6          1  target_diningroom_IDS01  memorize     7   322.0   642.0   216
# 7          1  target_diningroom_IDS01  memorize     8   363.0   832.0   389
# 8          1  target_diningroom_IDS01  memorize     9   369.0   935.0   139
# 9          1  target_diningroom_IDS01  memorize    10    99.0   796.0   276
# 10         1  target_diningroom_IDS01  memorize    11   176.0   735.0   230
# ...

# %%
import pandas as pd

# %%
eye_file = eye_file.groupby(["subj"]).mean().reset_index()
eye_file
# Out:
#     subj       fixN      locs_1      locs_2        durs     SCamp     Order
# 0      1  20.111255  358.614732  503.261261  261.563758  4.716637  1.490191
# 1      2  18.678184  390.035854  513.255800  278.929136  4.591678  1.451537
# 2      3  22.074231  330.554968  528.876113  239.699789  4.042834  1.529951
# 3      4  14.983831  359.590893  489.306375  375.258348  4.267996  1.505097
# 4      5  17.091352  319.887995  494.665325  268.079974  4.861164  1.500000
# 5      6  21.102854  411.610999  507.816347  251.191437  4.388973  1.512549
# 6      7  15.823093  366.927160  476.032577  358.930791  3.584488  1.505297
# 7      8  16.984122  380.904096  559.924573  284.358584  3.955553  1.455839
# 8      9  18.113218  375.837574  473.612722  300.409195  5.003399  1.500000
# 9     10  21.509710  390.911324  512.738639  253.976265  2.666991  1.501319
# 10    11  16.350016  384.218391  442.349222  334.080144  4.905213  1.514557
# ...

# %%
eye_file.to_csv("Eye_R.csv")
